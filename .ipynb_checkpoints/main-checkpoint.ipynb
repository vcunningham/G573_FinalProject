# %%
#Coded by Zoey Colglazier, Vincent Cunningham, and Isabel Winter in April 2020.

# %%
#Section 1: web-scraping
#A: Google API information
#B: Webscraper class
#C: method to get shows
#D: method to save shows to csv
#E: method to get show venue, geocode data
#hkhk

# %%
import requests
import json
import csv
import io
import os
from bs4 import BeautifulSoup as bsoup

Google_Api = "https://maps.googleapis.com/maps/api/geocode/json"
my_key = "AIzaSyCvJvds_095Hs0qpEg2SIxH9_SNsct-G8s"
headers = {
    "User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.106 Safari/537.36"
}

class WebScraper():
    collection = []
    city = ""
    
    def __init__(self):
        self.Rurl = "https://www.livenation.com/" 
        
    def geocoding(self, address):
        pm = {
            "address": address,
            "key": "AIzaSyCvJvds_095Hs0qpEg2SIxH9_SNsct-G8s"
        }
        response = requests.get(url = Google_Api, params = pm, headers=headers)
        #print(response.url)
        json_zips = response.json() 
        list_json = json_zips["results"]
        #print(list_json)
        unlist_json = list_json[0]
        #print(unlist_json)
        address_components = unlist_json["address_components"]
        self.city = address_components[2]["long_name"]
        #print(self.city)
        
    def show_collect(self):
        #print(self.city)
        par = {
            "key" : "AIzaSyCvJvds_095Hs0qpEg2SIxH9_SNsct-G8s"
        }
        app_url = self.Rurl
        
        print(app_url)
        
        show_req = requests.get(url=app_url, params = par, headers=headers)

        soup = bsoup(show_req.content, 'html.parser')
        #print(soup)
        shows = soup.find_all("div", class_="detail-card")
        #print(shows[1])
            
        for s in shows:
            venue = s.find('div', 'description').string
            #print(venue)
            params = {
                "key" : "AIzaSyCvJvds_095Hs0qpEg2SIxH9_SNsct-G8s",
                'address': venue,
                'inputtype':'textentry'
            }
            print(params)
            vres = requests.get(url = Google_Api, params = params, headers=headers)
            json_zips = vres.json() 
            print(json_zips)
            list_json = json_zips["results"]
            #print(list_json)
            unlist_json = list_json[0]
            #print(unlist_json)
            address_components = unlist_json["geometry"]
            #print(address_components)
            ven_lat = address_components['location']['lat']
            ven_lng = address_components['location']['lng']
            band = s.find('div', 'header').string
            date = s.find('span', class_='event-date').string

            show_info = [date, band, venue, ven_lat, ven_lng]
            self.collection.append(show_info)
            print("Finished: " + str(show_info))
        #print(self.collection) 
        
    def save_shows(self):
        titles = ["date", "band", "venue", "latitude", "longitude"]
        with io.open('shows.csv', 'wt', encoding='utf-8', newline="") as csvfile:
            filewriter = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            filewriter.writerow(titles)
            for row in self.collection:
                #print(row[0])
                filewriter.writerow([row[0], row[1].encode('utf-8'), row[2], row[3], row[4]]) #row[0], row[1], row[2], row[3]]
                #row.save_img(path)
            #print("House saved")
            csvfile.close()
            
    #getters
    def get_zipcode(self):
        return self.zipcode
    def get_img(self):
        return self.img_collection

# %%
scrape = WebScraper()
scrape.geocoding('550 N Park St, Madison, WI, 53706')
scrape.show_collect()
# Out:
# https://www.livenation.com/
# {'key': 'AIzaSyCvJvds_095Hs0qpEg2SIxH9_SNsct-G8s', 'address': None, 'inputtype': 'textentry'}
# {'error_message': "Invalid request. Missing the 'address', 'components', 'latlng' or 'place_id' parameter.", 'results': [], 'status': 'INVALID_REQUEST'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-ef5d368136d5> in <module>
#       1 scrape = WebScraper()
#       2 scrape.geocoding('550 N Park St, Madison, WI, 53706')
# ----> 3 scrape.show_collect()
#
# <ipython-input-7-145cab64e6f2> in show_collect(self)
#      65             list_json = json_zips["results"]
#      66             #print(list_json)
# ---> 67             unlist_json = list_json[0]
#      68             #print(unlist_json)
#      69             address_components = unlist_json["geometry"]
#
# IndexError: list index out of range

# %%
scrape.save_shows()

# %%
#Section 2: Point in polygon
#A: Define bounding box around campus
#B: Check if venues are within box.
#C: Save shows at those venues to csv.

# %%
from shapely.geometry import Point,  MultiPoint, LineString, Polygon, shape
import json
import pylab
import geopandas as gpd
import pandas as pd
from numpy import asarray

# %%
points = [(-89.0000, 42.9555), (-89.6555, 42.9555), (-89.6555, 43.3555), (-89.0000, 43.3555)] #these can be altered, just using ones from previous lab
#points = [(42.9555,-89.0000), (42.9555, -89.6555), (43.3555, -89.6555), (43.3555, -89.0000)]
box = Polygon(points)
csv=pd.read_csv('shows.csv', encoding='unicode_escape')
gdf=gpd.GeoDataFrame(data=csv,geometry=gpd.points_from_xy(x=csv.longitude, y=csv.latitude))
in_shows = []
gdf.plot()

def fill_polygon(polygon, o):
    pts = asarray(polygon.exterior)
    pylab.fill(pts[:,0],pts[:,1], o, alpha=0.8)
fill_polygon(box, "green")

for index, row in gdf.iterrows():
    pt = Point(row.longitude, row.latitude)
    if pt.within(box):
        in_shows.append(pt)
#print(in_photos)

# %%
#Section 3: Network connectivity/shortest route.
#A: Shortest route to Science Hall for each venue (walking and driving)
#B: Which venue has the shortest route?

# %%
import networkx as nx #importing a lot of stuff
import numpy as np
import pandas as pd
import osmnx as ox
import geopandas as gpd
import requests
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
ox.config(use_cache=True, log_console=True)

# %%
# get the network for a place
mad_G = ox.graph_from_place('Madison, WI, USA') #designame place
fig, ax = ox.plot_graph(mad_G) #plot thhe lines/nodes
ox.save_graph_shapefile(mad_G, 'Madison')#save file

# %%
# calculate the shortest path from science hall to Majestic theater
route = nx.shortest_path(mad_G, 4527217526,1375424620) #designating two points on map for shortest route
ox.plot_graph_route(mad_G, route, fig_height=20, fig_width=50) #plot route
# Out:
# (<Figure size 3600x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x212aad8db08>)

# %%
# calculate the shortest path from science hall to the sylvee
route = nx.shortest_path(mad_G, 4527217526, 5370926464) #designating two points on map for shortest route
ox.plot_graph_route(mad_G, route, fig_height=20, fig_width=50) #plot route
# Out:
# (<Figure size 3600x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x212f79b0748>)

# %%
# calculate the shortest path from science hall to high noon saloon
route = nx.shortest_path(mad_G, 4527217526, 5370926470) #designating two points on map for shortest route
ox.plot_graph_route(mad_G, route, fig_height=20, fig_width=50) #plot route
# Out:
# (<Figure size 3600x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x212898e2988>)

# %%
# calculate the shortest path from science hall to the orpheum
route = nx.shortest_path(mad_G, 4527217526, 4801881478) #designating two points on map for shortest route

ox.plot_graph_route(mad_G, route, fig_height=20, fig_width=50) #plot route
# Out:
# (<Figure size 3600x1440 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2128e639108>)

# %%
#Visualizations with CARTO

# %%
import pandas as pd
import geopandas as gpd
from cartoframes.auth import set_default_credentials

set_default_credentials('creds1.json')

df = pd.read_csv('shows.csv')

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(x=df.longitude, y=df.latitude))
gdf.head()
# Out:
#           date                                               band  \
# 0  TUE, Aug 18  b'M\xc3\xb6tley Cr\xc3\xbce/Def Leppard/Poison...
# 1  SUN, Aug 30                                        b'Maroon 5'
# 2   SAT, Jun 6                         b'Journey with Pretenders'
# 3  SUN, Jul 12  b'Santana / Earth, Wind & Fire: Miraculous Sup...
# 4  FRI, Nov 13                b'Joe Rogan: The Sacred Clown Tour'
#
#                                                venue   latitude  longitude  \
# 0                         Miller Park, Milwaukee, WI  43.027978 -87.971150
# 1  American Family Insurance Amphitheater - Summe...  43.027287 -87.897496
# 2         Alpine Valley Music Theatre, East Troy, WI  42.738004 -88.433850
# 3  American Family Insurance Amphitheater - Summe...  43.027287 -87.897496
# 4                        Fiserv Forum, Milwaukee, WI  43.045080 -87.917386
#
#                      geometry
# 0  POINT (-87.97115 43.02798)
# 1  POINT (-87.89750 43.02729)
# ...

# %%
from cartoframes.viz import Map, Layer
from cartoframes.data.services import Isolines
from cartoframes.viz import isolines_style
from cartoframes.viz import popup_element

isochrones_gdf, _ = Isolines().isochrones(gdf, [200, 500, 900], mode='walk', exclusive=True)
#print(isochrones_gdf.head())
#print(_)

isochrones_map = Map([
    Layer(
        isochrones_gdf
    )
], viewport={'zoom': 40, 'latitude': 43.0731, 'longitude': -89.4012})
isochrones_map

Layer(isochrones_gdf, isolines_style(palette='Emrld'))
# Out:
# Success! Isolines created correctly
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
# ...

# %%
import requests
import json
import pandas as pd
import geopandas as gpd
import csv
import io
import os

majcount=0
sylcount=0
orphcount=0
hncount=0
from csv import reader
from csv import writer
with open('shows.csv') as obj:
    showcsv=csv.reader(obj)
    for row in showcsv:
        #print(row)
        if row[2]=="Majestic Theatre, Madison, WI":
            majcount+=1
            #print(majcount)
        elif row[2]=="The Sylvee, Madison, WI":
            sylcount+=1
        elif row[2]=='Orpheum Theater, Madison, WI':
            orphcount+=1
        elif row[2]=="High Noon Saloon, Madison, WI":
                hncount+=1
titlelist = ['venue', 'latitude', 'longitude', 'shows']
mhold=["Majestic Theatre, Madison, WI", 43.0745219, -89.3808955, majcount]
shold=['The Sylvee, Madison, WI', 43.0806397, -89.374313, sylcount]
ohold=['Orpheum Theater, Madison, WI', 43.074929, -89.3887878, orphcount]
hhold=['High Noon Saloon, Madison, WI', 43.079581, -89.3764842, hncount]
biglist = [mhold, shold, ohold, hhold]
print(biglist)
# df=pd.DataFrame(biglist)
# # print(df)
# df.to_csv('tempcsv.csv', index='False')
# newdf = pd.read_csv('tempcsv.csv')
# #print(newdf)
# gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(x=df[1], y=df[2]))
# # print(gdf)

with io.open('num_shows.csv', 'wt', encoding='utf-8', newline="") as csvfile:
            filewriter = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            filewriter.writerow(titlelist)
            for row in biglist:
                print(row)
                filewriter.writerow(row) #row[0], row[1], row[2], row[3]]
                #row.save_img(path)
            #print("House saved")
            csvfile.close()
# Out:
# [['Majestic Theatre, Madison, WI', 43.0745219, -89.3808955, 14], ['The Sylvee, Madison, WI', 43.0806397, -89.374313, 1], ['Orpheum Theater, Madison, WI', 43.074929, -89.3887878, 1], ['High Noon Saloon, Madison, WI', 43.079581, -89.3764842, 3]]
# ['Majestic Theatre, Madison, WI', 43.0745219, -89.3808955, 14]
# ['The Sylvee, Madison, WI', 43.0806397, -89.374313, 1]
# ['Orpheum Theater, Madison, WI', 43.074929, -89.3887878, 1]
# ['High Noon Saloon, Madison, WI', 43.079581, -89.3764842, 3]

# %%
import pandas as pd
import geopandas as gpd
from cartoframes.auth import set_default_credentials

set_default_credentials('creds1.json')

df = pd.read_csv('num_shows.csv')

gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(x=df.longitude, y=df.latitude))
gdf.head()
# Out:
#                            venue   latitude  longitude  shows  \
# 0  Majestic Theatre, Madison, WI  43.074522 -89.380895     14
# 1        The Sylvee, Madison, WI  43.080640 -89.374313      1
# 2   Orpheum Theater, Madison, WI  43.074929 -89.388788      1
# 3  High Noon Saloon, Madison, WI  43.079581 -89.376484      3
#
#                      geometry
# 0  POINT (-89.38090 43.07452)
# 1  POINT (-89.37431 43.08064)
# 2  POINT (-89.38879 43.07493)
# 3  POINT (-89.37648 43.07958)

# %%
from cartoframes.viz import Map, Layer
from cartoframes.viz import size_continuous_style
from cartoframes.viz import popup_element
from cartoframes.viz import formula_widget, category_widget, histogram_widget

proportional_map = Map(
    Layer(
        gdf,
        style=size_continuous_style(
           'shows',
            opacity=0,
            stroke_color='green',
            stroke_width=2,
            size_range=[5,40]
        ),
        popup_hover = [
            popup_element('venue', 'Venue'),
            popup_element('shows', 'Shows')
        ],
    )
)
proportional_map
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
csv=pd.read_csv('shows.csv', encoding='unicode_escape')
#print(csv)
from datetime import datetime

lst = []

for s in csv["date"]:
    s += " 2020"
    print(s)
    dt = datetime.strptime(s, "%a, %b %d %Y")
    lst.append(dt)
    
days = [0,0,0,0,0,0,0] #starts with monday as pos 0 and sunday as 6, result tallies the number of times it occured
    
for i in lst:
    days[i.weekday()] += 1
    
print(days)
# Out:
# TUE, Aug 18 2020
# SUN, Aug 30 2020
# SAT, Jun 6 2020
# SUN, Jul 12 2020
# FRI, Nov 13 2020
# SAT, Oct 31 2020
# TUE, Sep 15 2020
# SAT, Aug 22 2020
# THU, Aug 27 2020
# SUN, Jul 26 2020
# TUE, Sep 22 2020
# FRI, Aug 7 2020
# TUE, Jun 2 2020
# SAT, Dec 12 2020
# WED, Jul 8 2020
# SAT, Jul 25 2020
# SAT, May 9 2020
# FRI, Jun 12 2020
# MON, Oct 19 2020
# SAT, May 9 2020
# FRI, May 22 2020
# FRI, Jul 31 2020
# MON, Jul 20 2020
# SAT, Jan 16 2020
# FRI, May 8 2020
# MON, Jun 1 2020
# MON, May 11 2020
# FRI, Jun 5 2020
# TUE, May 19 2020
# SAT, Jun 6 2020
# SAT, May 16 2020
# WED, May 6 2020
# THU, May 21 2020
# WED, Jun 3 2020
# TUE, May 12 2020
# FRI, Jun 26 2020
# [4, 6, 3, 3, 8, 9, 3]

# %%
# Out:
# [4, 6, 3, 3, 8, 9, 3]
